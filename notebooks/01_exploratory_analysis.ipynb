# %% [markdown]
# # EEG Data Exploratory Analysis
# Initial exploration and visualization of the EEG dataset

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# TODO: Load and explore EEG data
